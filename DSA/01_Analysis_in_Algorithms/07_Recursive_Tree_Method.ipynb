# %% [markdown]
# <h3>Recursive Tree Method:</h3>
#
#  - Used when we have more than one recursive term.
#  - Here, instead of substitution we use a recursive tree method where we break down the problem into smaller subproblems to find the solution.
#  - In this method, we draw a recurrence tree and calculate the time taken by every level of the tree.
#  - Finally, we sum the work done at all levels.
#  - To draw the recurrence tree, we start from the given recurrence and keep drawing till we find a pattern among levels.
#  - The pattern is typically arithmetic or geometric series.
#  - Each node represents the cost incurred at various levels of recursion.
#  - To find the total cost, costs of all levels are summed up.

# %% [markdown]
# Let's understand using below example:
# <pre>
#     T(n) = T(n/2) + T(n/2) + n
# </pre>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <h3>Recursive Tree Method - Problem 2</h3>

# %% [markdown]
# Consider below recurrence relation:
# <pre>
#     T(n) = T(n/5) + T(4n/5) + n
# </pre>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <h3>Recursive Method - Problem 3</h3>

# %% [markdown]
# Consider below recurrence relation:
# <pre>
#     T(n) = T(n/2) + T(n/3) + T(n/5) + c
# </pre>

# %% [markdown]
# ![RR.priya.recursive_tree.08.png](attachment:RR.priya.recursive_tree.08.png)
