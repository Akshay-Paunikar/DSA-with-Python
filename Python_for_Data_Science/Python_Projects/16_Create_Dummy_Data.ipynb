# %% [markdown]
# <h3>Create Dummy Data using Python</h3>

# %% [markdown]
# To create dummy data using Python, we can use the faker library. The faker library generates fake data randomly. If you have never used this library before, you can easily install it by using the pip command mentioned below in your command prompt or terminal:
#
#  - pip install faker

# %%
# !pip install faker
# Out:
# Collecting faker
#   Downloading Faker-25.2.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: python-dateutil>=2.4 in d:\anaconda\envs\deep_learning\lib\site-packages (from faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in d:\anaconda\envs\deep_learning\lib\site-packages (from python-dateutil>=2.4->faker) (1.16.0)
# Downloading Faker-25.2.0-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB 640.0 kB/s eta 0:00:03
#     --------------------------------------- 0.0/1.8 MB 487.6 kB/s eta 0:00:04
#    -- ------------------------------------- 0.1/1.8 MB 983.0 kB/s eta 0:00:02
#    ---- ----------------------------------- 0.2/1.8 MB 1.0 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.2/1.8 MB 1.1 MB/s eta 0:00:02
#    ------- -------------------------------- 0.3/1.8 MB 1.2 MB/s eta 0:00:02
#    -------- ------------------------------- 0.4/1.8 MB 1.2 MB/s eta 0:00:02
#    ---------- ----------------------------- 0.5/1.8 MB 1.2 MB/s eta 0:00:02
#    ----------- ---------------------------- 0.5/1.8 MB 1.2 MB/s eta 0:00:02
#    ----------- ---------------------------- 0.5/1.8 MB 1.2 MB/s eta 0:00:02
#    -------------- ------------------------- 0.6/1.8 MB 1.2 MB/s eta 0:00:01
#    --------------- ------------------------ 0.7/1.8 MB 1.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.7/1.8 MB 1.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.8/1.8 MB 1.2 MB/s eta 0:00:01
#    ------------------ --------------------- 0.8/1.8 MB 1.2 MB/s eta 0:00:01
#    ------------------- -------------------- 0.9/1.8 MB 1.2 MB/s eta 0:00:01
#    -------------------- ------------------- 0.9/1.8 MB 1.2 MB/s eta 0:00:01
#    --------------------- ------------------ 1.0/1.8 MB 1.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.0/1.8 MB 1.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.1/1.8 MB 1.1 MB/s eta 0:00:01
#    ------------------------ --------------- 1.1/1.8 MB 1.1 MB/s eta 0:00:01
#    ------------------------- -------------- 1.1/1.8 MB 1.1 MB/s eta 0:00:01
#    -------------------------- ------------- 1.2/1.8 MB 1.1 MB/s eta 0:00:01
#    --------------------------- ------------ 1.2/1.8 MB 1.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.3/1.8 MB 1.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.3/1.8 MB 1.0 MB/s eta 0:00:01
#    ------------------------------ --------- 1.4/1.8 MB 1.0 MB/s eta 0:00:01
#    ------------------------------ --------- 1.4/1.8 MB 1.0 MB/s eta 0:00:01
#    ------------------------------- -------- 1.4/1.8 MB 1.0 MB/s eta 0:00:01
#    --------------------------------- ------ 1.5/1.8 MB 1.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.5/1.8 MB 1.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.6/1.8 MB 1.0 MB/s eta 0:00:01
#    ------------------------------------ --- 1.6/1.8 MB 1.0 MB/s eta 0:00:01
#    ------------------------------------- -- 1.7/1.8 MB 1.0 MB/s eta 0:00:01
#    -------------------------------------- - 1.7/1.8 MB 1.0 MB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 1.0 MB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 1.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 977.1 kB/s eta 0:00:00
# Installing collected packages: faker
# Successfully installed faker-25.2.0

# %%
from faker import Faker
import pandas as pd

# %%
fake = Faker()

# %%
print(fake.name())
print(fake.address())
print(fake.text())
# Out:
# Lauren Wright
# 179 Brooks Village Apt. 245
# Garciastad, IN 51948
# Method attack test. Before sometimes data air interesting difficult ten. Share year sit reality light nice inside.

# %% [markdown]
# Every time you will run this code, you will get different results. Now let’s see how to create fake data for creating a dummy dataset using Python.
#
# The Faker().profile() method returns fake data about job profiles containing 13 columns.

# %%
data = [fake.profile() for i in range(100)]
data = pd.DataFrame(data)
data.head()
# Out:
#                                      job                   company  \
# 0                               Best boy        Gutierrez and Sons
# 1                  Multimedia specialist  Leonard, Green and Price
# 2                           Nurse, adult                Boyd-Crane
# 3  English as a foreign language teacher             Sanchez Group
# 4                    Information officer             Andrews-Blake
#
#            ssn                                          residence  \
# 0  579-49-3009  73721 Monique Crossroad Suite 321\nJosephhaven...
# 1  426-85-1295  50458 Johnson Junctions Apt. 622\nSouth Donald...
# 2  506-66-5937    7231 Lee Loop Suite 768\nSouth Amanda, IN 28879
# 3  823-02-5565  95550 Estrada Grove Suite 006\nEast Jeremyberg...
# 4  394-22-6657      31299 Lopez Vista\nEast Ashleymouth, ME 38708
#
#             current_location blood_group  \
# 0    (58.890765, 116.629070)          B-
# 1   (42.8651655, -57.444842)          O+
# 2   (-10.0517075, 48.617767)          B-
# 3  (-46.4915875, 116.805316)         AB+
# 4     (14.625389, 35.777373)          O-
#
#                                              website      username  \
# 0           [https://haas.com/, https://scott.info/]        hreyes
# 1  [https://cooper-brown.com/, http://www.anderso...      fpearson
# 2  [https://www.grant-bolton.com/, http://orozco....        cpatel
# 3  [https://mann-white.com/, https://www.grant-he...         nlowe
# 4  [https://www.mccoy.biz/, https://www.blevins-d...  padillajacob
#
#               name sex                                            address  \
# 0       Jose Moore   M       1054 Wheeler Rest\nBenjaminborough, AR 62788
# 1       Lisa Moody   F                       USNV Hernandez\nFPO AE 45067
# 2    Stacey Romero   F    42653 Nixon Views Suite 229\nJameston, VT 30002
# 3  Caitlin Ballard   F  7499 Jeffrey Forges Suite 990\nLake Mistyport,...
# 4     Leslie Hicks   F   62369 Morris Cove Suite 635\nRileyfurt, GA 76671
#
#                         mail   birthdate
# 0            wboyd@gmail.com  1935-10-21
# 1         dalehuff@yahoo.com  1952-10-06
# 2          bbailey@yahoo.com  1924-06-13
# 3  larrywilliamson@yahoo.com  1911-12-15
# 4      fmckinney@hotmail.com  1922-12-22
